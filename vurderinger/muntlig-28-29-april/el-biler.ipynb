# %%
import pandas as pd

# %%
df = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
df
# Out:
#         VIN (1-10)     County            City State  Postal Code  Model Year  \
# 0       WBY8P6C58K       King         Seattle    WA      98115.0        2019
# 1       5YJSA1DN4D     Kitsap       Bremerton    WA      98312.0        2013
# 2       5YJSA1E26J       King            Kent    WA      98042.0        2018
# 3       WBY2Z2C54E       King        Bellevue    WA      98004.0        2014
# 4       5YJXCDE23J       King        Bellevue    WA      98004.0        2018
# ...            ...        ...             ...   ...          ...         ...
# 186874  JTMEB3FVXM  Snohomish       Arlington    WA      98223.0        2021
# 186875  7SAYGAEEXP  Snohomish        Stanwood    WA      98292.0        2023
# 186876  3FA6P0SUXK       King          Auburn    WA      98001.0        2019
# 186877  7SAYGDEE1P     Pierce          Tacoma    WA      98422.0        2023
# 186878  7SAYGDEE1R    Douglas  East Wenatchee    WA      98802.0        2024
#
# ...

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df[(df["Make"] == "BMW") & (df["Model"] == "I3")]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       WBY8P6C58K      King        Seattle    WA      98115.0        2019
# 32      WBY8P4C50K      King        Seattle    WA      98177.0        2019
# 44      WBY1Z6C36H      King        Seattle    WA      98109.0        2017
# 108     WBY1Z2C52F      King      Sammamish    WA      98075.0        2015
# 157     WBY8P4C51K      King        Seattle    WA      98199.0        2019
# ...            ...       ...            ...   ...          ...         ...
# 186555  WBY1Z2C50E    Yakima         Yakima    WA      98901.0        2014
# 186573  WBY1Z4C54E    Pierce     Gig Harbor    WA      98335.0        2014
# 186638  WBY1Z4C58G      King        Redmond    WA      98053.0        2016
# 186786  WBY7Z4C50J      King         Vashon    WA      98070.0        2018
# 186800  WBY1Z2C5XE  San Juan  Friday Harbor    WA      98250.0        2014
#
#        Make Model                   Electric Vehicle Type  \
# ...

# %%
df["Make"].value_counts().head(10).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df[df["Make"] == "TESLA"]["City"].value_counts()
# Out:
# City
# Seattle      12237
# Bellevue      5739
# Redmond       4092
# Bothell       3700
# Sammamish     3484
#              ...
# Cinebar          1
# Mililani         1
# Palo Alto        1
# Rich             1
# Uniontown        1
# Name: count, Length: 570, dtype: int64

# %%
df["Electric Range"].value_counts()
# Out:
# Electric Range
# 0      98765
# 215     6441
# 32      4337
# 25      4268
# 220     4059
#        ...
# 95         3
# 11         3
# 51         2
# 57         2
# 46         1
# Name: count, Length: 103, dtype: int64

# %%
df[df["Electric Range"] == 6441]
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []
